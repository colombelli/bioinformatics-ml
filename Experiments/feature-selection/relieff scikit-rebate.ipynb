# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import make_pipeline
from skrebate import ReliefF
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('/home/colombelli/Documents/datasets/assembler/prad/intersect.csv', index_col=0)

# %%
import pickle
smpl_path = "/home/colombelli/Documents/experiments/Experiments22_ago/prad/hom_relieff/fold_sampling.pkl"

with open(smpl_path, 'rb') as file:
    sampling = pickle.load(file)

# %%
tr, ts = sampling[2]
print(len(tr), len(ts))
# Out:
# 84 110

# %%
x = df.iloc[tr, :].values
y = df.iloc[tr, -1:]['class'].values

# %%
rf = ReliefF(n_neighbors=10, n_jobs=-1)
rf.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-b3eb2c09f2b5> in <module>
#       1 rf = ReliefF(n_neighbors=10, n_jobs=-1)
# ----> 2 rf.fit(x, y)
#
# ~/.local/lib/python3.8/site-packages/skrebate/relieff.py in fit(self, X, y)
#     192        # Run remainder of algorithm (i.e. identification of 'neighbors' for each instance, and feature scoring).------------
#     193         # Stores feature importance scores for ReliefF or respective Relief-based algorithm.
# --> 194         self.feature_importances_ = self._run_algorithm()
#     195
#     196         # Delete the internal distance array because it is no longer needed
#
# ~/.local/lib/python3.8/site-packages/skrebate/relieff.py in _run_algorithm(self)
#     450
#     451         # Call the scoring method for the ReliefF algorithm
# --> 452         scores = np.sum(Parallel(n_jobs=self.n_jobs)(delayed(
# ...

# %%
from ReliefF import ReliefF

# %%
fs = ReliefF(n_neighbors=10)
fs.fit(x, y)

# %%
fs.top_features
# Out:
# array([15236,  1363,  1721, ...,  7707,  1450,  4903])

# %%
df.iloc[:, :]
# Out:
#                                  GLIS1     PXMP2    ATP5SL    RHBDF1  \
# TCGA-3C-AAAU-01A-11R-A41B-07 -0.870027  0.045579  0.151762  0.039360
# TCGA-3C-AALI-01A-11R-A41B-07 -1.032134 -0.397413  1.418824  1.683815
# TCGA-3C-AALJ-01A-31R-A41B-07 -0.415394  0.268249  0.505125  0.377335
# TCGA-3C-AALK-01A-11R-A41B-07  2.104695  0.557531  0.458651  0.974175
# TCGA-4H-AAAK-01A-12R-A41B-07  2.231959 -0.268249  0.760619  0.675061
# ...                                ...       ...       ...       ...
# TCGA-WT-AB44-01A-11R-A41B-07 -0.041433 -1.364766 -1.459257  2.592532
# TCGA-XX-A899-01A-11R-A36F-07  1.184317  0.422171  0.401896  0.535916
# TCGA-XX-A89A-01A-11R-A36F-07  0.791318 -1.727564 -0.760619  0.791318
# TCGA-Z7-A8R5-01A-42R-A41B-07 -0.053873  1.082579  0.941548  0.677659
# TCGA-Z7-A8R6-01A-11R-A41B-07 -0.012427  1.304709  0.685480  0.987516
#
#                                  ARL11     ZFP37    BTN3A2      LGI3  \
# ...
