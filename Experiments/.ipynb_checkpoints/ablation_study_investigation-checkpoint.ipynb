# %%
import os

target_path="/home/colombelli/Documents/arrayexpress/breast/hyb_borda_borda/"

path_dirs = None
for _, subdirs, _ in os.walk(target_path):
    path_dirs = subdirs
    break
    
folds = len([i for i in path_dirs if "fold_" in i])

# %%
from distutils.dir_util import copy_tree
copy_tree(target_path, "/home/colombelli/Documents/arrayexpress/test/")
# Out:
# ['/home/colombelli/Documents/arrayexpress/test/pr_aucs_results.csv',
#  '/home/colombelli/Documents/arrayexpress/test/accuracies_results.csv',
#  '/home/colombelli/Documents/arrayexpress/test/experiment_info.txt',
#  '/home/colombelli/Documents/arrayexpress/test/selection/4/bootstrap_sampling_23.pkl',
#  '/home/colombelli/Documents/arrayexpress/test/selection/4/bootstrap_sampling_27.pkl',
#  '/home/colombelli/Documents/arrayexpress/test/selection/4/bootstrap_sampling_2.pkl',
#  '/home/colombelli/Documents/arrayexpress/test/selection/4/bootstrap_sampling_37.pkl',
#  '/home/colombelli/Documents/arrayexpress/test/selection/4/bootstrap_sampling_19.pkl',
#  '/home/colombelli/Documents/arrayexpress/test/selection/4/bootstrap_sampling_35.pkl',
#  '/home/colombelli/Documents/arrayexpress/test/selection/4/bootstrap_sampling_17.pkl',
#  '/home/colombelli/Documents/arrayexpress/test/selection/4/bootstrap_sampling_18.pkl',
# ...

# %%
import pandas as pd

# %%
r = pd.read_csv("/home/colombelli/Documents/arrayexpress/test/fold_1/bootstrap_1/gd.csv", index_col=0)
r
# Out:
#            rank
# TCN1          1
# UGT2B28       2
# PEG3          3
# CPB1          4
# RNF128        5
# ...         ...
# NARFL     20541
# ARHGEF11  20542
# DPH2      20543
# SSUH2     20544
# ESRRA     20545
#
# [20545 rows x 1 columns]
