# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import StratifiedShuffleSplit

# %%
mine = "/home/colombelli/Documents/Experiments16_jul/micarrNPN_Het_borda/fold_sampling.pkl"
with open(mine, 'rb') as f:
    msamp = pickle.load(f)
    
msamp
# Out:
# [(['TCGA-C8-A12U-01A-11R-A115-07',
#    'TCGA-AR-A1AR-01A-31R-A137-07',
#    'TCGA-BH-A0DL-11A-13R-A115-07',
#    'TCGA-BH-A0BV-11A-31R-A089-07',
#    'TCGA-A2-A0YF-01A-21R-A109-07',
#    'TCGA-E2-A15A-01A-11R-A12D-07',
#    'TCGA-D8-A141-01A-11R-A115-07',
#    'TCGA-BH-A18J-11A-31R-A12D-07',
#    'TCGA-BH-A0DV-11A-22R-A12P-07',
#    'TCGA-E2-A1B5-01A-21R-A12P-07',
#    'TCGA-BH-A0DK-11A-13R-A089-07',
#    'TCGA-B6-A0I8-01A-11R-A034-07',
#    'TCGA-BH-A1ET-11B-23R-A137-07',
#    'TCGA-A2-A0YG-01A-21R-A109-07',
#    'TCGA-BH-A0DI-01A-21R-A12P-07',
#    'TCGA-BH-A0AU-11A-11R-A12P-07',
#    'TCGA-A7-A0DC-11A-41R-A089-07',
#    'TCGA-BH-A18J-01A-11R-A12D-07',
#    'TCGA-BH-A0BW-11A-12R-A115-07',
#    'TCGA-BH-A0HF-01A-11R-A056-07',
#    'TCGA-BH-A0B7-11A-34R-A115-07',
#    'TCGA-AR-A1AK-01A-21R-A12P-07',
#    'TCGA-BH-A0BZ-11A-61R-A12P-07',
#    'TCGA-BH-A1EO-11A-31R-A137-07',
#    'TCGA-BH-A0HA-11A-31R-A12P-07',
#    'TCGA-A8-A08O-01A-21R-A056-07',
#    'TCGA-E2-A1BC-01A-11R-A12P-07',
# ...

# %%
df = pd.read_csv('/home/colombelli/Documents/datasets/assembler/brca_micarr_npn.csv', index_col=0)
df
# Out:
#                                X15E1.2   X2..PDE      X7A5      A1BG  \
# TCGA-A1-A0SD-01A-11R-A115-07 -0.025539 -0.515257  1.145865  1.326113
# TCGA-A1-A0SE-01A-11R-A084-07 -1.845034  0.754251 -0.594494  0.145203
# TCGA-A1-A0SH-01A-11R-A084-07 -0.962187 -0.630318  0.682929  1.053336
# TCGA-A1-A0SJ-01A-11R-A084-07 -1.296385  1.622164  0.197021  1.060707
# TCGA-A1-A0SK-01A-12R-A084-07  0.227481 -0.996281 -1.622164 -1.003237
# ...                                ...       ...       ...       ...
# TCGA-E2-A1B5-01A-21R-A12P-07  0.379005 -0.549504 -0.731918 -0.347217
# TCGA-E2-A1B6-01A-31R-A12P-07 -0.128022  0.240598  0.495954  0.955499
# TCGA-E2-A1BC-01A-11R-A12P-07 -1.129780  0.776960 -0.210052 -0.609753
# TCGA-E2-A1BC-11A-32R-A12P-07 -0.351737  0.491156 -1.508684 -2.410722
# TCGA-E2-A1BD-01A-11R-A12P-07 -0.453164 -1.780823  0.140904 -0.666956
#
#                                  A2BP1       A2M     A2ML1   A3GALT2  \
# ...

# %%
df.iloc[:, -1:]
# Out:
#                               class
# TCGA-A1-A0SD-01A-11R-A115-07      1
# TCGA-A1-A0SE-01A-11R-A084-07      1
# TCGA-A1-A0SH-01A-11R-A084-07      1
# TCGA-A1-A0SJ-01A-11R-A084-07      1
# TCGA-A1-A0SK-01A-12R-A084-07      1
# ...                             ...
# TCGA-E2-A1B5-01A-21R-A12P-07      1
# TCGA-E2-A1B6-01A-31R-A12P-07      1
# TCGA-E2-A1BC-01A-11R-A12P-07      1
# TCGA-E2-A1BC-11A-32R-A12P-07      0
# TCGA-E2-A1BD-01A-11R-A12P-07      1
#
# [593 rows x 1 columns]

# %%
sss = StratifiedShuffleSplit(n_splits=5, random_state=0)
sss.get_n_splits(df.iloc[:, :-1], df.iloc[:, -1:])
# Out:
# 5

# %%
print(sss)
# Out:
# StratifiedShuffleSplit(n_splits=5, random_state=0, test_size=None,
#             train_size=None)

# %%
list(sss.split(df.iloc[:, :-1], df.iloc[:, -1:]))[0]
# Out:
# (array([123, 154, 468,  82,  23, 560,  52, 146, 265, 273, 129, 156, 276,
#          26, 306, 590, 399, 539, 356, 109,  14, 454, 268, 542, 287, 257,
#         556, 127,  24, 527, 360, 236, 320, 544,  63, 282, 387, 456, 445,
#          49, 577,  94, 241, 233, 572,  61, 309, 366, 239, 489, 523, 162,
#         500, 398,  78, 246, 111,  56, 562,  80, 301, 487,  55,  30, 362,
#         585,  60, 441, 330, 168, 326, 466, 405,   9, 342, 472, 116, 436,
#         495, 376, 336, 407, 565, 420, 245, 536, 393, 503, 551, 324, 115,
#         507, 279, 275, 260, 359, 514,   6, 573, 323, 203, 462, 216, 161,
#         361, 252, 232, 435, 506, 184, 205, 144,  39, 197,  13, 411,  50,
#         412, 442, 183, 261,  72, 476, 132, 211, 526,   7, 416, 478, 341,
#         149, 133, 374, 353, 294, 139, 492, 266,  36, 449, 538,  83, 584,
#         153, 583, 508, 550,  37,  92, 292,  31, 130,  41,  46, 104, 440,
#         179,  99,  40, 477,  10,  27, 413, 191, 337,  66, 567, 172, 357,
# ...

# %%
len(list(sss.split(df.iloc[:, :-1], df.iloc[:, -1:]))[0][1])
# Out:
# 60

# %%
len(msamp[0][1])
# Out:
# 119

# %%
from efsassembler.StratifiedKFold import StratifiedKFold

# %%
skf = StratifiedKFold(0, df, "class", 5)

# %%
folds = list(skf.split())

# %%
len(folds[0][0])
# Out:
# 100

# %%
len(folds[0][1])
# Out:
# 119

# %%
len(df.iloc[:, :-1])
# Out:
# 593

# %%
len(list(sss.split(df.iloc[:, :-1], df.iloc[:, -1:]))[0][0])
# Out:
# 533

# %%
X=df.iloc[:, :-1]
y=df.iloc[:, -1:]

# %%
df.loc[:, ['class']]
# Out:
#                               class
# TCGA-A1-A0SD-01A-11R-A115-07      1
# TCGA-A1-A0SE-01A-11R-A084-07      1
# TCGA-A1-A0SH-01A-11R-A084-07      1
# TCGA-A1-A0SJ-01A-11R-A084-07      1
# TCGA-A1-A0SK-01A-12R-A084-07      1
# ...                             ...
# TCGA-E2-A1B5-01A-21R-A12P-07      1
# TCGA-E2-A1B6-01A-31R-A12P-07      1
# TCGA-E2-A1BC-01A-11R-A12P-07      1
# TCGA-E2-A1BC-11A-32R-A12P-07      0
# TCGA-E2-A1BD-01A-11R-A12P-07      1
#
# [593 rows x 1 columns]

# %%
df.loc[:, df.columns != 'class']
# Out:
#                                X15E1.2   X2..PDE      X7A5      A1BG  \
# TCGA-A1-A0SD-01A-11R-A115-07 -0.025539 -0.515257  1.145865  1.326113
# TCGA-A1-A0SE-01A-11R-A084-07 -1.845034  0.754251 -0.594494  0.145203
# TCGA-A1-A0SH-01A-11R-A084-07 -0.962187 -0.630318  0.682929  1.053336
# TCGA-A1-A0SJ-01A-11R-A084-07 -1.296385  1.622164  0.197021  1.060707
# TCGA-A1-A0SK-01A-12R-A084-07  0.227481 -0.996281 -1.622164 -1.003237
# ...                                ...       ...       ...       ...
# TCGA-E2-A1B5-01A-21R-A12P-07  0.379005 -0.549504 -0.731918 -0.347217
# TCGA-E2-A1B6-01A-31R-A12P-07 -0.128022  0.240598  0.495954  0.955499
# TCGA-E2-A1BC-01A-11R-A12P-07 -1.129780  0.776960 -0.210052 -0.609753
# TCGA-E2-A1BC-11A-32R-A12P-07 -0.351737  0.491156 -1.508684 -2.410722
# TCGA-E2-A1BD-01A-11R-A12P-07 -0.453164 -1.780823  0.140904 -0.666956
#
#                                  A2BP1       A2M     A2ML1   A3GALT2  \
# ...

# %%
from sklearn.model_selection import StratifiedKFold
skl_skf = StratifiedKFold(n_splits=5, shuffle=True)
skl_skf.get_n_splits(X, y)
# Out:
# 5

# %%
len(list(skl_skf.split(X, y))[4][1])
# Out:
# 118

# %%
len(folds[4][1])
# Out:
# 118

# %%
loc = list(skl_skf.split(X, y))[4][1]

# %%
np.unique(np.ndarray.flatten(df.iloc[loc, -1:].values), return_counts=True)
# Out:
# (array([0, 1]), array([ 12, 106]))

# %%
np.unique(np.ndarray.flatten(df.iloc[:, -1:].values), return_counts=True)
# Out:
# (array([0, 1]), array([ 62, 531]))

# %%
(12*100)/(106+12)
# Out:
# 10.169491525423728

# %%
(62*100)/(62+531)
# Out:
# 10.45531197301855

# %%
df.iloc[loc]
# Out:
#                                X15E1.2   X2..PDE      X7A5      A1BG  \
# TCGA-A1-A0SH-01A-11R-A084-07 -0.962187 -0.630318  0.682929  1.053336
# TCGA-A2-A04R-01A-41R-A109-07 -0.374442  1.204604 -1.046021  1.917733
# TCGA-A2-A0CQ-01A-21R-A034-07  0.119446  0.128022  1.378389  0.218758
# TCGA-A2-A0CS-01A-11R-A115-07  1.145865  1.801422  1.822802  1.446459
# TCGA-A2-A0CU-01A-12R-A034-07  0.038313  0.661669 -1.346590  0.171056
# ...                                ...       ...       ...       ...
# TCGA-E2-A15E-01A-11R-A12D-07 -0.853676  0.175375  0.034054  0.890793
# TCGA-E2-A15M-01A-11R-A12D-07 -1.346590 -0.048963  0.476830 -0.865918
# TCGA-E2-A15S-01A-11R-A115-07  2.283435 -0.083086 -2.283435  1.637875
# TCGA-E2-A1B0-01A-11R-A12P-07  0.841559  0.614870  0.800070 -1.046021
# TCGA-E2-A1BC-01A-11R-A12P-07 -1.129780  0.776960 -0.210052 -0.609753
#
#                                  A2BP1       A2M     A2ML1   A3GALT2  \
# ...
