# %%
import pandas as pd
import numpy as np

# %%
genes_rank = "/home/colombelli/Documents/Experiments31_jul/hyb_brca_rnaseq_genes_intersec_E3/selection/agg_ranking_th1.csv"
gdf = pd.read_csv(genes_rank, index_col=0)
genes = list(gdf.index)
genes
# Out:
# ['LOC283867',
#  'GABRD',
#  'FGF1',
#  'PPAPDC1A',
#  'HSD17B6',
#  'SLC24A2',
#  'GLRA4',
#  'LOC729467',
#  'COL10A1',
#  'ADAMTS14',
#  'CCL11',
#  'HHATL',
#  'CILP2',
#  'PKHD1L1',
#  'CST2',
#  'IGFBP6',
#  'BGN',
#  'CLEC3B',
#  'AADACL2',
#  'COMP',
#  'C1QTNF6',
#  'CHRNA6',
#  'PGA5',
#  'COL6A6',
#  'CYMP',
#  'FAM70A',
#  'LALBA',
#  'FN1',
#  'HCN2',
#  'CEBPA',
#  'CTHRC1',
#  'CXCL12',
#  'CLEC5A',
#  'RAX2',
#  'DCN',
#  'EEPD1',
#  'ENTHD1',
#  'C11orf87',
#  'LOC415056',
#  'CST1',
#  'ACAN',
#  'FTMT',
#  'BMP8A',
#  'TCF21',
#  'HBA1',
#  'P2RY12',
#  'RPLP0P2',
#  'CAB39L',
#  'FLJ10357',
#  'ADRBK2',
#  'TTLL10',
#  'GPR120',
#  'CDADC1',
#  'CC2D2A',
#  'SLC22A12',
#  'ACSM2A',
#  'CNN1',
#  'WISP1',
#  'ESYT1',
#  'CST4',
#  'RPE65',
#  'LOC100133920',
#  'TRPM6',
#  'HADH',
#  'CCND2',
#  'AHNAK',
#  'GRM4',
#  'SPRR2F',
#  'CDH4',
#  'ALDH18A1',
#  'IBSP',
#  'C19orf69',
#  'AGPAT2',
#  'CCDC141',
#  'CXCR7',
#  'ADAMTSL4',
#  'RHOXF1',
#  'C5orf13',
# ...

# %%
top5 = genes[0:5]
top10 = genes[0:10]
top15 = genes[0:15]
top20 = genes[0:20]

# %%
train_df_path = "/home/colombelli/Documents/up_files/brca_rnaseq_genes_intersec.csv"
train_df = pd.read_csv(train_df_path, index_col=0)
train_df
# Out:
#                                  GLIS1     PXMP2    ATP5SL    RHBDF1  \
# TCGA-3C-AAAU-01A-11R-A41B-07 -0.870027  0.045579  0.151762  0.039360
# TCGA-3C-AALI-01A-11R-A41B-07 -1.032134 -0.397413  1.418824  1.683815
# TCGA-3C-AALJ-01A-31R-A41B-07 -0.415394  0.268249  0.505125  0.377335
# TCGA-3C-AALK-01A-11R-A41B-07  2.104695  0.557531  0.458651  0.974175
# TCGA-4H-AAAK-01A-12R-A41B-07  2.231959 -0.268249  0.760619  0.675061
# ...                                ...       ...       ...       ...
# TCGA-WT-AB44-01A-11R-A41B-07 -0.041433 -1.364766 -1.459257  2.592532
# TCGA-XX-A899-01A-11R-A36F-07  1.184317  0.422171  0.401896  0.535916
# TCGA-XX-A89A-01A-11R-A36F-07  0.791318 -1.727564 -0.760619  0.791318
# TCGA-Z7-A8R5-01A-42R-A41B-07 -0.053873  1.082579  0.941548  0.677659
# TCGA-Z7-A8R6-01A-11R-A41B-07 -0.012427  1.304709  0.685480  0.987516
#
#                                  ARL11     ZFP37    BTN3A2      LGI3  \
# ...

# %%
path = "/home/colombelli/Documents/datasets/cumida/intersect_genes/GSE22820.csv"
test_df = pd.read_csv(path, index_col=0)
test_df
# Out:
#                   GLIS1     PXMP2    ATP5SL    RHBDF1     ARL11     ZFP37  \
# GSM563920_1   -0.764102  0.279391  1.505713 -1.276176  1.164476 -0.670197
# GSM563922_3   -2.081046  0.538888  0.918493 -1.200140 -1.130162 -0.974740
# GSM563923_4    1.237311 -1.316957 -0.603310  0.716401 -0.497103  0.693124
# GSM563924_5    0.241390 -0.891380  0.614274 -0.788578 -0.317778  1.034070
# GSM563925_6   -1.316957  0.788578  0.560115 -0.279391  0.693124  1.561746
# ...                 ...       ...       ...       ...       ...       ...
# GSM564101_182  0.376221  0.166315  1.237311  0.456124 -0.395966  0.395966
# GSM564102_183 -0.092119 -1.065067  1.765927 -0.036806 -0.356614  1.316957
# GSM564103_184  0.517888 -0.538888  0.376221  0.603310 -0.581584  0.203717
# GSM564104_185  1.561746  0.000000 -0.018400  0.279391 -0.560115  0.456124
# GSM564105_186  0.435907  0.110608  0.974740  0.203717 -1.065067  0.337136
#
#                  BTN3A2      LGI3     TYRO3      SDF4  ...    SLC4A4  \
# ...

# %%
test_df.loc[:, top5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-f638be2aef8d> in <module>
# ----> 1 test_df.loc[:, top5]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1287                 continue
#    1288
# -> 1289             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1290
#    1291         return retval
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics

def get_x(df):
    return df.loc[:, df.columns != 'class']
    
def get_y(df):
    return df.loc[:, ['class']].T.values[0]

def get_probs_positive_class(pred):
        positive_probs = []

        for prediction in pred:
            positive_probs.append(prediction[1])
        return positive_probs

# %%
clf = SVC(gamma='auto', probability=True)

tr_top = train_df.loc[:, genes[0:100]+['class']]
ts_top = test_df.loc[:, genes[0:100]+['class']]

X_train = get_x(tr_top)
y_train = get_y(tr_top)

X_test = get_x(ts_top)
y_test = get_y(ts_top)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-fd2ac79ff092> in <module>
#       2
#       3 tr_top = train_df.loc[:, genes[0:100]+['class']]
# ----> 4 ts_top = test_df.loc[:, genes[0:100]+['class']]
#       5
#       6 X_train = get_x(tr_top)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1287                 continue
#    1288
# -> 1289             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1290
#    1291         return retval
#
# ...

# %%
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.5155709342560554

# %%
genes
# Out:
# ['LOC283867',
#  'GABRD',
#  'FGF1',
#  'PPAPDC1A',
#  'HSD17B6',
#  'SLC24A2',
#  'GLRA4',
#  'LOC729467',
#  'COL10A1',
#  'ADAMTS14',
#  'CCL11',
#  'HHATL',
#  'CILP2',
#  'PKHD1L1',
#  'CST2',
#  'IGFBP6',
#  'BGN',
#  'CLEC3B',
#  'AADACL2',
#  'COMP',
#  'C1QTNF6',
#  'CHRNA6',
#  'PGA5',
#  'COL6A6',
#  'CYMP',
#  'FAM70A',
#  'LALBA',
#  'FN1',
#  'HCN2',
#  'CEBPA',
#  'CTHRC1',
#  'CXCL12',
#  'CLEC5A',
#  'RAX2',
#  'DCN',
#  'EEPD1',
#  'ENTHD1',
#  'C11orf87',
#  'LOC415056',
#  'CST1',
#  'ACAN',
#  'FTMT',
#  'BMP8A',
#  'TCF21',
#  'HBA1',
#  'P2RY12',
#  'RPLP0P2',
#  'CAB39L',
#  'FLJ10357',
#  'ADRBK2',
#  'TTLL10',
#  'GPR120',
#  'CDADC1',
#  'CC2D2A',
#  'SLC22A12',
#  'ACSM2A',
#  'CNN1',
#  'WISP1',
#  'ESYT1',
#  'CST4',
#  'RPE65',
#  'LOC100133920',
#  'TRPM6',
#  'HADH',
#  'CCND2',
#  'AHNAK',
#  'GRM4',
#  'SPRR2F',
#  'CDH4',
#  'ALDH18A1',
#  'IBSP',
#  'C19orf69',
#  'AGPAT2',
#  'CCDC141',
#  'CXCR7',
#  'ADAMTSL4',
#  'RHOXF1',
#  'C5orf13',
# ...

# %%
fold1 = "/home/colombelli/Documents/Experiments31_jul/sin_brca_rnaseq_genes_intersec_E10/fold_1/rf.csv"
selection = "/home/colombelli/Documents/Experiments31_jul/sin_brca_rnaseq_genes_intersec_E10/selection/rf.csv"
gdf = pd.read_csv(fold1, index_col=0)
genes = list(gdf.index)
genes
# Out:
# ['GNG13',
#  'PLCZ1',
#  'GABRA4',
#  'AADACL2',
#  'RAX2',
#  'IBSP',
#  'SLC22A12',
#  'OTC',
#  'FEZF2',
#  'PMP2',
#  'OR2B6',
#  'FCRL4',
#  'SGCZ',
#  'NR0B1',
#  'CAV3',
#  'HIST1H3B',
#  'ADCY8',
#  'GALR1',
#  'LHCGR',
#  'MOGAT1',
#  'CSN3',
#  'KRT74',
#  'HIST1H2AJ',
#  'CPA1',
#  'SLC7A14',
#  'WBSCR28',
#  'LALBA',
#  'TEX19',
#  'MRGPRX2',
#  'CA6',
#  'LOC100133920',
#  'EPB42',
#  'NXNL1',
#  'CSN1S1',
#  'HTR4',
#  'HIST1H2AL',
#  'HIST1H4D',
#  'RGR',
#  'TMEFF2',
#  'DCAF12L1',
#  'TPPP2',
#  'MARCH4',
#  'DKK4',
#  'GBX2',
#  'IFNB1',
#  'SCT',
#  'HHATL',
#  'SERPINB13',
#  'CSN2',
#  'NPY2R',
#  'DCT',
#  'NLGN4Y',
#  'SLC24A2',
#  'CCL7',
#  'RTBDN',
#  'KCNH5',
#  'GRIN2B',
#  'HIST1H1B',
#  'PTTG3P',
#  'CAPZA3',
#  'NMU',
#  'GPR123',
#  'HIST1H3F',
#  'SLC39A12',
#  'AGXT',
#  'MS4A15',
#  'GLP2R',
#  'HBE1',
#  'KCNA4',
#  'UCP1',
#  'LRRTM1',
#  'XKR4',
#  'RPE65',
#  'OOEP',
#  'FAM181A',
#  'FGF5',
#  'GPR112',
#  'CCL24',
#  'OLAH',
#  'KCTD4',
# ...

# %%
tr_df = pd.read_csv("/home/colombelli/Documents/up_files/brca_rnaseq_genes_intersec.csv", index_col=0)

# %%
ts_df = pd.read_csv("/home/colombelli/Documents/datasets/cumida/intersect_genes/GSE22820.csv", index_col=0)

# %%
clf = SVC(gamma='auto', probability=True)

tr_top = tr_df.loc[:, genes[0:10]+['class']]
ts_top = ts_df.loc[:, genes[0:10]+['class']]

X_train = get_x(tr_top)
y_train = get_y(tr_top)

X_test = get_x(ts_top)
y_test = get_y(ts_top)

clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9280575539568345

# %%
gdf = pd.read_csv(selection, index_col=0)
genes = list(gdf.index)
genes
# Out:
# ['IQCF2',
#  'DEFB114',
#  'TTTY12',
#  'TTTY13',
#  'TTTY7',
#  'TTTY6',
#  'TTTY11',
#  'PLA2G2E',
#  'TSSK2',
#  'AMELY',
#  'TTTY8',
#  'C11orf40',
#  'DEFB127',
#  'TEX28',
#  'HSFX1',
#  'TTTY5',
#  'TECTB',
#  'ACTRT2',
#  'DAOA',
#  'TAAR9',
#  'OR5H1',
#  'TAAR2',
#  'WFDC9',
#  'OR7A17',
#  'KRTAP4.5',
#  'TBC1D21',
#  'TMEM225',
#  'OR5L2',
#  'OR5I1',
#  'TAS2R16',
#  'KRTAP9.8',
#  'VN1R4',
#  'SRY',
#  'KRTAP4.2',
#  'TTTY2',
#  'GSC2',
#  'POM121L12',
#  'GSX1',
#  'GPHB5',
#  'OR7A10',
#  'OR1A1',
#  'PRG3',
#  'KRTAP13.1',
#  'PRM1',
#  'CRYGB',
#  'LOC100287704',
#  'LELP1',
#  'CRYGA',
#  'DEFB123',
#  'LGALS13',
#  'OR13C4',
#  'OR52A1',
#  'VCY',
#  'PRAMEF10',
#  'TTTY10',
#  'OR10C1',
#  'HNRNPCL1',
#  'DEFB129',
#  'OR2W1',
#  'OR7C2',
#  'FAM24A',
#  'NPVF',
#  'REG3G',
#  'TAAR5',
#  'FGF6',
#  'OR1D2',
#  'IFNA8',
#  'DEFB118',
#  'CYLC2',
#  'CABP2',
#  'LCE2B',
#  'TAAR8',
#  'DEFA6',
#  'PRM3',
#  'KRTAP9.4',
#  'BHLHE23',
#  'CSHL1',
#  'KRTAP9.9',
# ...

# %%
clf = SVC(gamma='auto', probability=True)

tr_top = tr_df.loc[:, genes[0:5]+['class']]
ts_top = ts_df.loc[:, genes[0:5]+['class']]

X_train = get_x(tr_top)
y_train = get_y(tr_top)

X_test = get_x(ts_top)
y_test = get_y(ts_top)

clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.920863309352518

# %%
clf = SVC(gamma='auto', probability=True)

tr_top = tr_df.loc[:, genes[-5:]+['class']]
ts_top = ts_df.loc[:, genes[-5:]+['class']]

X_train = get_x(tr_top)
y_train = get_y(tr_top)

X_test = get_x(ts_top)
y_test = get_y(ts_top)

clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9784172661870504

# %%
genes[-10:]
# Out:
# ['ATP6V0D2',
#  'GRIN1',
#  'ANGPTL6',
#  'HIST1H1E',
#  'FAM57B',
#  'LY6H',
#  'PTPRN',
#  'HAPLN1',
#  'CHRNA6',
#  'DQX1']

# %%
def get_acc(genes):
    clf = SVC(gamma='auto', probability=True)

    tr_top = tr_df.loc[:, genes+['class']]
    ts_top = ts_df.loc[:, genes+['class']]

    X_train = get_x(tr_top)
    y_train = get_y(tr_top)

    X_test = get_x(ts_top)
    y_test = get_y(ts_top)

    clf.fit(X_train, y_train)
    print(clf.score(X_test, y_test))
    return

# %%
import random

# %%
for i in range(0,10):
    rand_genes = random.choices(genes, k=5)
    get_acc(rand_genes)
# Out:
# 0.8992805755395683
# 0.9064748201438849
# 0.9136690647482014
# 0.9280575539568345
# 0.9064748201438849
# 0.9496402877697842
# 0.9424460431654677
# 0.9136690647482014
# 0.920863309352518
# 0.8848920863309353

# %%
ts_df = pd.read_csv("/home/colombelli/Documents/datasets/cumida/intersect_genes/GSE70947.csv", index_col=0)

# %%
gdf = pd.read_csv(fold1, index_col=0)
genes = list(gdf.index)

clf = SVC(gamma='auto', probability=True)

tr_top = tr_df.loc[:, genes[0:10]+['class']]
ts_top = ts_df.loc[:, genes[0:10]+['class']]

X_train = get_x(tr_top)
y_train = get_y(tr_top)

X_test = get_x(ts_top)
y_test = get_y(ts_top)

clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.5121107266435986

# %%
gdf = pd.read_csv(selection, index_col=0)
genes = list(gdf.index)

clf = SVC(gamma='auto', probability=True)

tr_top = tr_df.loc[:, genes[0:10]+['class']]
ts_top = ts_df.loc[:, genes[0:10]+['class']]

X_train = get_x(tr_top)
y_train = get_y(tr_top)

X_test = get_x(ts_top)
y_test = get_y(ts_top)

clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.49480968858131485

# %%
gdf = pd.read_csv(selection, index_col=0)
genes = list(gdf.index)

clf = SVC(gamma='auto', probability=True)

tr_top = tr_df.loc[:, genes[-10:]+['class']]
ts_top = ts_df.loc[:, genes[-10:]+['class']]

X_train = get_x(tr_top)
y_train = get_y(tr_top)

X_test = get_x(ts_top)
y_test = get_y(ts_top)

clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.532871972318339

# %%
for i in range(0,10):
    rand_genes = random.choices(genes, k=10)
    get_acc(rand_genes)
# Out:
# 0.5605536332179931
# 0.5190311418685121
# 0.4982698961937716
# 0.5086505190311419
# 0.5294117647058824
# 0.532871972318339
# 0.5086505190311419
# 0.5051903114186851
# 0.5017301038062284
# 0.5259515570934256

# %%
ts_df = pd.read_csv("/home/colombelli/Documents/datasets/cumida/intersect_genes/GSE42568.csv", index_col=0)

# %%
gdf = pd.read_csv(fold1, index_col=0)
genes = list(gdf.index)

clf = SVC(gamma='auto', probability=True)

tr_top = tr_df.loc[:, genes[0:10]+['class']]
ts_top = ts_df.loc[:, genes[0:10]+['class']]

X_train = get_x(tr_top)
y_train = get_y(tr_top)

X_test = get_x(ts_top)
y_test = get_y(ts_top)

clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8793103448275862

# %%
gdf = pd.read_csv(selection, index_col=0)
genes = list(gdf.index)

clf = SVC(gamma='auto', probability=True)

tr_top = tr_df.loc[:, genes[0:10]+['class']]
ts_top = ts_df.loc[:, genes[0:10]+['class']]

X_train = get_x(tr_top)
y_train = get_y(tr_top)

X_test = get_x(ts_top)
y_test = get_y(ts_top)

clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8706896551724138

# %%
gdf = pd.read_csv(selection, index_col=0)
genes = list(gdf.index)

clf = SVC(gamma='auto', probability=True)

tr_top = tr_df.loc[:, genes[-10:]+['class']]
ts_top = ts_df.loc[:, genes[-10:]+['class']]

X_train = get_x(tr_top)
y_train = get_y(tr_top)

X_test = get_x(ts_top)
y_test = get_y(ts_top)

clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8620689655172413

# %%
for i in range(0,10):
    rand_genes = random.choices(genes, k=10)
    get_acc(rand_genes)
# Out:
# 0.9655172413793104
# 0.8793103448275862
# 0.8879310344827587
# 0.8620689655172413
# 0.896551724137931
# 0.8879310344827587
# 0.9224137931034483
# 0.9137931034482759
# 0.9741379310344828
# 0.853448275862069
