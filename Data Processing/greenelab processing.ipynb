# %%
import pandas as pd
import numpy as np

import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter


def load_RDS(file_path):

    read_RDS = robjects.r['readRDS']
    return read_RDS(file_path)



def load_csv(file_path):
    return pd.read_csv(file_path, index_col=0)



def pandas_to_r(df):

    with localconverter(robjects.default_converter + pandas2ri.converter):
        r_from_pandas_df = robjects.conversion.py2rpy(df)
    return r_from_pandas_df



def r_to_pandas(df):
    with localconverter(robjects.default_converter + pandas2ri.converter):
            pandas_from_r_df = robjects.conversion.rpy2py(df)
    return pandas_from_r_df

# %%
tr = r_to_pandas(load_RDS("/home/colombelli/Documents/datasets/integrated/tr_10.rds"))
#te = r_to_pandas(load_RDS("/home/colombelli/Documents/datasets/integrated/te_10.rds"))

# %%
te
# Out:
#          gene  TCGA-A1-A0SE-01  TCGA-A1-A0SK-01  TCGA-A1-A0SM-01  \
# 1        A1BG         0.268141         0.112202         0.422753
# 2       A2BP1         0.000000         0.000000         0.005975
# 3         A2M         0.574076         0.279585         0.443158
# 4       A2ML1         0.000386         0.009632         0.000123
# 5      A4GALT         0.124052         0.029502         0.139292
# ...       ...              ...              ...              ...
# 15820  ZYG11A         0.127837         0.344282         0.086952
# 15821  ZYG11B         0.390920         0.647331         0.663571
# 15822     ZYX         0.467132         0.000000         0.636706
# 15823   ZZEF1         0.336329         0.645573         0.439119
# 15824    ZZZ3         0.243050         0.302046         0.327009
#
#        TCGA-A1-A0SO-01  TCGA-A2-A04N-01  TCGA-A2-A04P-01  TCGA-A2-A04U-01  \
# 1             0.404035         0.254958         0.145791         0.414148
# 2             0.000000         0.000000         0.000000         0.000000
# 3             0.274900         0.464253         0.451502         0.822042
# 4             0.008794         0.000155         0.393396         0.207323
# 5             0.005751         0.308154         0.066993         0.115319
# ...                ...              ...              ...              ...
# 15820         0.239084         0.098103         0.456376         0.285791
# 15821         0.859292         0.268846         0.221209         0.116167
# 15822         0.193248         0.406465         0.612472         0.493956
# 15823         0.290230         0.397892         0.227610         0.193593
# 15824         0.198556         0.197823         0.140221         0.286469
#
#        TCGA-A2-A0CL-01  TCGA-A2-A0CY-01  ...  TCGA-E2-A156-01  \
# 1             0.139667         0.292643  ...         0.168360
# 2             0.035051         0.000000  ...         0.000000
# 3             0.664277         0.432986  ...         0.323958
# 4             0.013841         0.002395  ...         0.000000
# 5             0.206096         1.000000  ...         0.051443
# ...                ...              ...  ...              ...
# 15820         0.396591         0.259267  ...         0.017571
# 15821         0.389981         0.000000  ...         0.358200
# 15822         0.506216         0.514627  ...         0.316195
# 15823         0.795820         0.108211  ...         0.663786
# 15824         0.162826         0.041597  ...         0.292641
#
#        TCGA-E2-A158-01  TCGA-E2-A15A-01  TCGA-E2-A15F-01  TCGA-E2-A15H-01  \
# 1             0.205209         0.154887         0.170546         0.082919
# 2             0.000000         0.000000         0.071855         0.000000
# 3             0.466475         0.501103         0.395590         0.431626
# 4             0.576520         0.002994         0.000330         0.003450
# 5             0.012884         0.411216         0.122843         0.490863
# ...                ...              ...              ...              ...
# 15820         0.721160         0.165479         0.131333         0.255077
# 15821         0.298762         0.257039         0.461496         0.332149
# 15822         0.835822         0.419887         0.380758         0.455266
# 15823         0.261287         0.576463         0.911542         0.382420
# 15824         0.386454         0.119273         0.222743         0.250574
#
#        TCGA-E2-A15M-01  TCGA-E2-A15S-01  TCGA-E2-A15T-01  TCGA-E2-A1B6-01  \
# 1             0.026400         0.230325         0.139556         0.161379
# 2             0.054595         0.027199         0.000000         0.000000
# 3             0.714412         0.390940         0.345773         0.561273
# 4             0.273418         0.002132         0.000245         0.325532
# 5             0.072580         0.236607         0.140599         0.075877
# ...                ...              ...              ...              ...
# 15820         0.185245         0.449054         0.449054         0.416464
# 15821         0.545469         0.538869         0.470028         0.236282
# 15822         0.293009         0.081470         0.205581         0.505915
# 15823         0.452939         0.559962         0.290897         0.311053
# 15824         0.315535         0.946434         0.259481         0.166806
#
#        TCGA-E2-A1BC-01
# 1             0.085433
# 2             0.060152
# 3             0.482218
# 4             0.000000
# 5             0.075515
# ...                ...
# 15820         0.207744
# 15821         0.693323
# 15822         0.279312
# 15823         0.417372
# 15824         0.304952
#
# [15824 rows x 173 columns]

# %%
tr
# Out:
#          gene  TCGA-A1-A0SD-01  TCGA-A1-A0SH-01  TCGA-A1-A0SJ-01  \
# 1        A1BG         0.579192         0.519611         0.519997
# 2       A2BP1         0.355881         0.094734         0.089840
# 3         A2M         0.167307         0.282465         0.358761
# 4       A2ML1         0.233645         0.223107         0.249177
# 5      A4GALT         0.493840         0.464239         0.681979
# ...       ...              ...              ...              ...
# 15820  ZYG11A         0.120614         0.080597         0.104962
# 15821  ZYG11B         0.250879         0.474049         0.448265
# 15822     ZYX         0.218184         0.519798         0.225251
# 15823   ZZEF1         0.249315         0.394906         0.282367
# 15824    ZZZ3         0.353404         0.253279         0.166010
#
#        TCGA-A2-A04Q-01  TCGA-A2-A04R-01  TCGA-A2-A04T-01  TCGA-A2-A04V-01  \
# 1             0.378792         0.682972         0.304446         0.435208
# 2             0.114833         0.070649         0.086455         0.105983
# 3             0.254517         0.126927         0.208158         0.160481
# 4             0.625214         0.268036         1.000000         0.287919
# 5             0.508566         0.427739         0.191185         0.318676
# ...                ...              ...              ...              ...
# 15820         0.291644         0.179365         0.308450         0.024855
# 15821         0.658593         0.722642         0.693692         0.452822
# 15822         0.419563         0.247667         0.459975         0.414877
# 15823         0.382775         0.192854         0.507342         0.215354
# 15824         0.260000         0.071404         0.228921         0.431013
#
#        TCGA-A2-A04X-01  TCGA-A2-A04Y-01  ...  TCGA-BH-A0BS-01  \
# 1             0.195887         0.398621  ...         0.155269
# 2             0.134804         0.146252  ...         0.017486
# 3             0.212418         0.207457  ...         0.218405
# 4             0.265817         0.265306  ...         0.002384
# 5             0.189786         0.813500  ...         0.156898
# ...                ...              ...  ...              ...
# 15820         0.200796         0.395835  ...         0.142830
# 15821         0.434559         0.465033  ...         0.596508
# 15822         0.204327         0.206899  ...         0.314886
# 15823         0.468641         0.480813  ...         0.678374
# 15824         0.267360         0.234514  ...         0.305019
#
#        TCGA-BH-A0E6-01  TCGA-BH-A0HP-01  TCGA-BH-A18G-01  TCGA-E2-A107-01  \
# 1             0.398537         0.302551         0.001975         0.283587
# 2             0.427622         1.000000         0.000000         0.000000
# 3             0.389917         0.450287         0.074664         0.184339
# 4             0.011433         0.000699         0.001626         0.003434
# 5             0.226603         0.130511         0.039514         0.209727
# ...                ...              ...              ...              ...
# 15820         0.201805         0.058264         0.000829         0.252683
# 15821         0.000000         0.439852         0.130121         0.107947
# 15822         1.000000         0.424009         0.514367         0.441604
# 15823         0.260406         0.308101         0.097034         0.661965
# 15824         0.212054         0.349743         0.267269         0.054720
#
#        TCGA-E2-A14N-01  TCGA-E2-A14O-01  TCGA-E2-A14P-01  TCGA-E2-A14S-01  \
# 1             0.036870         0.507013         0.207934         0.223779
# 2             0.000000         0.000000         0.000000         0.000000
# 3             0.000000         0.015162         0.197462         0.297678
# 4             0.358733         0.000348         0.002256         0.001347
# 5             0.000000         0.434824         0.055719         0.100076
# ...                ...              ...              ...              ...
# 15820         1.000000         0.319377         0.153657         0.052144
# 15821         0.595960         0.065658         1.000000         0.363505
# 15822         0.493013         0.236063         0.410836         0.326656
# 15823         0.160524         0.000000         0.253343         0.190676
# 15824         0.428067         0.001214         0.122828         0.291606
#
#        TCGA-E2-A14V-01
# 1             0.205902
# 2             0.000000
# 3             0.148556
# 4             0.001715
# 5             0.124533
# ...                ...
# 15820         0.359078
# 15821         0.394605
# 15822         0.537749
# 15823         0.437628
# 15824         0.105778
#
# [15824 rows x 349 columns]

# %%
tr = tr.T

# %%
tr.columns = tr.iloc[0]

# %%
tr = tr.drop(tr.index[0])

# %%
clin = "/home/colombelli/Documents/datasets/integrated/BRCAClin.tsv"
clindf = pd.read_csv(clin, sep='\t')
clindf = clindf.set_index('Sample')

rna = "/home/colombelli/Documents/datasets/integrated/BRCARNASeqClin.tsv"
rnadf = pd.read_csv(rna, sep='\t')
rnadf = rnadf.set_index('_SAMPLE_ID')

# %%
tr
# Out:
# gene                 A1BG      A2BP1        A2M        A2ML1     A4GALT  \
# TCGA-A1-A0SD-01  0.579192   0.355881   0.167307     0.233645    0.49384
# TCGA-A1-A0SH-01  0.519611  0.0947341   0.282465     0.223107   0.464239
# TCGA-A1-A0SJ-01  0.519997  0.0898402   0.358761     0.249177   0.681979
# TCGA-A2-A04Q-01  0.378792   0.114833   0.254517     0.625214   0.508566
# TCGA-A2-A04R-01  0.682972  0.0706494   0.126927     0.268036   0.427739
# ...                   ...        ...        ...          ...        ...
# TCGA-E2-A14N-01   0.03687          0          0     0.358733          0
# TCGA-E2-A14O-01  0.507013          0  0.0151624  0.000348106   0.434824
# TCGA-E2-A14P-01  0.207934          0   0.197462   0.00225625  0.0557192
# TCGA-E2-A14S-01  0.223779          0   0.297678   0.00134745   0.100076
# TCGA-E2-A14V-01  0.205902          0   0.148556   0.00171517   0.124533
#
# gene                 A4GNT       AAAS      AACS      AADAC    AADACL2  ...  \
# TCGA-A1-A0SD-01   0.257919    0.27959  0.227816   0.076479   0.076063  ...
# TCGA-A1-A0SH-01   0.315343   0.196451   0.30925  0.0688088   0.100188  ...
# TCGA-A1-A0SJ-01   0.307154  0.0963079  0.287224   0.135319  0.0899502  ...
# TCGA-A2-A04Q-01   0.347419   0.298768  0.197277  0.0701101   0.115226  ...
# TCGA-A2-A04R-01    0.21316   0.282515  0.255774  0.0550278   0.099646  ...
# ...                    ...        ...       ...        ...        ...  ...
# TCGA-E2-A14N-01          0   0.211987  0.234903          0          0  ...
# TCGA-E2-A14O-01  0.0711596          1  0.550821    0.12659          0  ...
# TCGA-E2-A14P-01          0   0.449301  0.287528          0          0  ...
# TCGA-E2-A14S-01   0.220458   0.680399  0.211019          0          0  ...
# TCGA-E2-A14V-01  0.0585147    0.44918  0.284886  0.0148891          0  ...
#
# gene               ZSWIM7       ZW10     ZWINT       ZXDB       ZXDC  \
# TCGA-A1-A0SD-01   0.28226  0.0919312  0.260321   0.848837  0.0574274
# TCGA-A1-A0SH-01  0.212721    0.12913  0.127629   0.506872   0.186675
# TCGA-A1-A0SJ-01  0.472408   0.144183  0.186943    0.87102   0.183909
# TCGA-A2-A04Q-01  0.387286   0.176989  0.322698   0.297737   0.390305
# TCGA-A2-A04R-01  0.537319  0.0917868  0.315019     0.7566   0.356408
# ...                   ...        ...       ...        ...        ...
# TCGA-E2-A14N-01  0.526233   0.783419  0.305058   0.285759  0.0576673
# TCGA-E2-A14O-01  0.505895   0.292313  0.650068  0.0551385   0.224838
# TCGA-E2-A14P-01         1   0.537658  0.561288   0.382832   0.513212
# TCGA-E2-A14S-01  0.303589  0.0206073  0.488543   0.269476   0.542893
# TCGA-E2-A14V-01  0.352296   0.478843   0.73051   0.441047   0.468602
#
# gene                ZYG11A     ZYG11B       ZYX     ZZEF1        ZZZ3
# TCGA-A1-A0SD-01   0.120614   0.250879  0.218184  0.249315    0.353404
# TCGA-A1-A0SH-01  0.0805971   0.474049  0.519798  0.394906    0.253279
# TCGA-A1-A0SJ-01   0.104962   0.448265  0.225251  0.282367     0.16601
# TCGA-A2-A04Q-01   0.291644   0.658593  0.419563  0.382775        0.26
# TCGA-A2-A04R-01   0.179365   0.722642  0.247667  0.192854   0.0714044
# ...                    ...        ...       ...       ...         ...
# TCGA-E2-A14N-01          1    0.59596  0.493013  0.160524    0.428067
# TCGA-E2-A14O-01   0.319377  0.0656581  0.236063         0  0.00121387
# TCGA-E2-A14P-01   0.153657          1  0.410836  0.253343    0.122828
# TCGA-E2-A14S-01  0.0521437   0.363505  0.326656  0.190676    0.291606
# TCGA-E2-A14V-01   0.359078   0.394605  0.537749  0.437628    0.105778
#
# [348 rows x 15824 columns]

# %%
rnadf.loc['TCGA-A1-A0SD-01']['sample type']
# Out:
# 'Primary Tumor'

# %%
rnadf['sample type'].unique()
# Out:
# array(['Primary Tumor', 'Metastatic', 'Solid Tissue Normal'], dtype=object)

# %%
classes = []

for sample in tr.index:
    
    stype = rnadf.loc[sample]['sample type']
    if stype == 'Primary Tumor' or stype == 'Metastatic':
        classes.append(1)
    elif stype == 'Solid Tissue Normal':
        classes.append(0)
    else:
        print("\nUnexpected class:", stype)
        print("Sample:", sample)
        
(np.array(classes) == 0).any()
# Out:
# False
