# %%
import GEOparse

# %%
path = "/home/colombelli/Documents/datasets/cumida/lung/GSE19188/"
gse = GEOparse.get_GEO(geo="GSE19188", destdir=path)
# Out:
# 20-Oct-2020 15:25:42 DEBUG utils - Directory /home/colombelli/Documents/datasets/cumida/lung/GSE19188/ already exists. Skipping.
# 20-Oct-2020 15:25:42 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE19nnn/GSE19188/soft/GSE19188_family.soft.gz to /home/colombelli/Documents/datasets/cumida/lung/GSE19188/GSE19188_family.soft.gz
# 100%|██████████| 79.8M/79.8M [01:04<00:00, 1.30MB/s]
# 20-Oct-2020 15:26:50 DEBUG downloader - Size validation passed
# 20-Oct-2020 15:26:50 DEBUG downloader - Moving /tmp/tmp2mfiim02 to /home/colombelli/Documents/datasets/cumida/lung/GSE19188/GSE19188_family.soft.gz
# 20-Oct-2020 15:26:50 DEBUG downloader - Successfully downloaded ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE19nnn/GSE19188/soft/GSE19188_family.soft.gz
# 20-Oct-2020 15:26:50 INFO GEOparse - Parsing /home/colombelli/Documents/datasets/cumida/lung/GSE19188/GSE19188_family.soft.gz:
# 20-Oct-2020 15:26:50 DEBUG GEOparse - DATABASE: GeoMiame
# ...

# %%
print()
print("GSM example:")
for gsm_name, gsm in gse.gsms.items():
    print("Name: ", gsm_name)
    print("Metadata:",)
    for key, value in gsm.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
    print ("Table data:",)
    print (gsm.table.head())
    break
# Out:
# GSM example:
# Name:  GSM475656
# Metadata:
#  - title : NSCLC EMC TB0069tu
#  - geo_accession : GSM475656
#  - status : Public on May 07 2010
#  - submission_date : Nov 25 2009
#  - last_update_date : Aug 28 2018
#  - type : RNA
#  - channel_count : 1
#  - source_name_ch1 : frozen tissue
#  - organism_ch1 : Homo sapiens
#  - taxid_ch1 : 9606
#  - characteristics_ch1 : tissue type: tumor, cell type: LCC, overall survival: 12.5, status: deceased, gender: M
#  - molecule_ch1 : total RNA
#  - extract_protocol_ch1 : Trizol extraction of total RNA was performed according to the manufacturer's instructions.
#  - label_ch1 : biotin
#  - label_protocol_ch1 : Biotinylated cRNA were prepared according to the standard Affymetrix protocol from 6 ug total RNA (Expression Analysis Technical Manual, 2001, Affymetrix).
# ...

# %%
print("GPL example:")
for gpl_name, gpl in gse.gpls.items():
    print("Name: ", gpl_name)
    print("Metadata:",)
    for key, value in gpl.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
    print("Table data:",)
    print(gpl.table.head())
    break
# Out:
# GPL example:
# Name:  GPL570
# Metadata:
#  - title : [HG-U133_Plus_2] Affymetrix Human Genome U133 Plus 2.0 Array
#  - geo_accession : GPL570
#  - status : Public on Nov 07 2003
#  - submission_date : Nov 07 2003
#  - last_update_date : Jun 18 2020
#  - technology : in situ oligonucleotide
#  - distribution : commercial
#  - organism : Homo sapiens
#  - taxid : 9606
#  - manufacturer : Affymetrix
# ...

# %%
gse.gpls['GPL570'].columns
# Out:
#                                                                         description
# ID                                Affymetrix Probe Set ID LINK_PRE:"https://www....
# GB_ACC                            GenBank Accession Number LINK_PRE:"http://www....
# SPOT_ID                                                         identifies controls
# Species Scientific Name           The genus and species of the organism represen...
# Annotation Date                   The date that the annotations for this probe a...
# Sequence Type
# Sequence Source                   The database from which the sequence used to d...
# Target Description
# Representative Public ID          The accession number of a representative seque...
# Gene Title                              Title of Gene represented by the probe set.
# Gene Symbol                       A gene symbol, when one is available (from Uni...
# ENTREZ_GENE_ID                    Entrez Gene Database UID LINK_PRE:"http://www....
# ...

# %%
gse.gsms["GSM475657"].columns
# Out:
#            description
# ID_REF
# VALUE   RMA normalized

# %%
gse.gsms["GSM475656"].table
# Out:
#                      ID_REF     VALUE
# 0                 1007_s_at  0.278536
# 1                   1053_at  0.460967
# 2                    117_at -0.272634
# 3                    121_at  0.293016
# 4                 1255_g_at  1.536637
# ...                     ...       ...
# 54670  AFFX-r2-Ec-bioC-5_at  0.542138
# 54671  AFFX-r2-Ec-bioD-3_at  0.411814
# 54672  AFFX-r2-Ec-bioD-5_at  0.363136
# 54673   AFFX-r2-P1-cre-3_at  0.232270
# 54674   AFFX-r2-P1-cre-5_at  0.254550
#
# [54675 rows x 2 columns]

# %%
ex = gse.gsms["GSM475656"].table.set_index('ID_REF').T
ex.rename(index={'VALUE': 'something'})
# Out:
# ID_REF     1007_s_at   1053_at    117_at    121_at  1255_g_at   1294_at  \
# something   0.278536  0.460967 -0.272634  0.293016   1.536637 -0.366586
#
# ID_REF      1316_at   1320_at  1405_i_at   1431_at  ...  \
# something  0.473545 -0.139187   0.887567 -0.087691  ...
#
# ID_REF     AFFX-r2-Bs-thr-M_s_at  AFFX-r2-Ec-bioB-3_at  AFFX-r2-Ec-bioB-5_at  \
# something              -2.570835               0.41873              0.443696
#
# ID_REF     AFFX-r2-Ec-bioB-M_at  AFFX-r2-Ec-bioC-3_at  AFFX-r2-Ec-bioC-5_at  \
# something              0.533803              0.553453              0.542138
#
# ID_REF     AFFX-r2-Ec-bioD-3_at  AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  \
# something              0.411814              0.363136              0.23227
#
# ID_REF     AFFX-r2-P1-cre-5_at
# something              0.25455
#
# [1 rows x 54675 columns]

# %%
probe = "1007_s_at"
probe2 = "AFFX-r2-P1-cre-5_at"

# %%
gpl = gse.gpls['GPL570'].table

# %%
any(gpl['ID'] == probe2)
# Out:
# False

# %%
probes = list(gse.gsms["GSM475656"].table['ID_REF'].values)

# %%
match = []
didnt_match = []
for probe in probes:
    if any(gpl['ID'] == probe):
        match.append(probe)
    else:
        didnt_match.append(probe)

# %%
len(match)
# Out:
# 54675

# %%
len(didnt_match)
# Out:
# 0

# %%
probes[-1]
# Out:
# 'AFFX-r2-P1-cre-5_at'

# %%
any(gpl['ID'] == probes[-1])
# Out:
# True

# %%
gpl.loc[gpl['ID'] == probe]
# Out:
#                         ID GB_ACC    SPOT_ID Species Scientific Name  \
# 54668  AFFX-r2-P1-cre-5_at    NaN  --Control            Homo sapiens
#
#       Annotation Date     Sequence Type                  Sequence Source  \
# 54668     Oct 6, 2014  Control sequence  Affymetrix Proprietary Database
#
#                                       Target Description  \
# 54668  Bacteriophage P1 /GEN=cre /DB_XREF=gb:X03453.1...
#
#       Representative Public ID Gene Title Gene Symbol ENTREZ_GENE_ID  \
# 54668         AFFX-r2-P1-cre-5        NaN         NaN            NaN
#
#       RefSeq Transcript ID Gene Ontology Biological Process  \
# 54668                  NaN                              NaN
#
#       Gene Ontology Cellular Component Gene Ontology Molecular Function
# 54668                              NaN                              NaN

# %%
gpl.loc[gpl['ID'] == probe2]
# Out:
# Empty DataFrame
# Columns: [ID, GB_ACC, SPOT_ID, Species Scientific Name, Annotation Date, Sequence Type, Sequence Source, Target Description, Representative Public ID, Gene Title, Gene Symbol, ENTREZ_GENE_ID, RefSeq Transcript ID, Gene Ontology Biological Process, Gene Ontology Cellular Component, Gene Ontology Molecular Function]
# Index: []

# %%
gsm_rows = []

for gsm_name, gsm in gse.gsms.items():
    row = gsm.table.set_index('ID_REF').T
    row = row.rename(index={'VALUE': gsm_name})
    gsm_rows.append(row)

# %%
import pandas as pd

# %%
df = pd.concat(gsm_rows)
df
# Out:
# ID_REF     1007_s_at   1053_at    117_at    121_at  1255_g_at   1294_at  \
# GSM475656   0.278536  0.460967 -0.272634  0.293016   1.536637 -0.366586
# GSM475657  -0.005102 -0.800087 -1.059395  0.053426  -0.141374  0.140578
# GSM475658  -0.619297 -0.233029 -0.121798 -0.604698  -0.401689  0.366297
# GSM475659  -0.400920 -0.474353 -0.721781 -0.140631  -0.166218  0.630699
# GSM475660  -0.025468 -0.575989 -0.320457  0.223255  -0.386274  0.421736
# ...              ...       ...       ...       ...        ...       ...
# GSM475807  -1.211480 -0.490503 -0.432617  0.317428  -0.152852  0.481527
# GSM475808   1.650433 -0.219517  1.105148 -0.477453  -0.118738 -0.917873
# GSM475809  -0.435173 -0.341717  0.361822  0.085279  -0.393415  0.567132
# GSM475810   0.074260 -0.340199 -0.661017 -0.030056   0.083503 -0.241787
# GSM475811  -0.392640 -0.053654 -0.732805  0.123111  -0.154219  0.293819
#
# ID_REF      1316_at   1320_at  1405_i_at   1431_at  ...  \
# ...

# %%
s = gpl.loc[gpl['ID'] == 'AFFX-r2-P1-cre-5_at']['Gene Symbol'].iloc[0]
s
# Out:
# nan

# %%
isinstance(s, str)
# Out:
# False

# %%
translation = {}
for col in df.columns:
    gene_symbol = gpl.loc[gpl['ID'] == col]['Gene Symbol'].iloc[0]
    if not isinstance(gene_symbol, str):
        del df[col]
    else:
        translation[col] = gene_symbol

# %%
for key, value in translation.items():
    if len(value.split('///')) > 1:
        translation[key] = value.split('///')[0][0:-1]

# %%
df = df.rename(columns=translation)

# %%
from copy import deepcopy
df2 = deepcopy(df)

# %%
df2.astype('float64').mean(axis=1, level=0)
# Out:
# ID_REF         DDR1      RFC2     HSPA6      PAX8    GUCA1A   MIR5193  \
# GSM475656  0.320602  0.417823 -0.038564  0.130232  0.713547 -0.425300
# GSM475657 -0.082611 -0.872701 -0.999178 -0.108468 -0.187532  0.195445
# GSM475658 -0.566773 -0.171459 -0.007490 -0.326087 -0.475106  0.480137
# GSM475659 -0.576433 -0.457648 -0.794457 -0.203678 -0.309903  0.648519
# GSM475660 -0.063671 -0.534894 -0.379396  0.203799  0.014586  0.509231
# ...             ...       ...       ...       ...       ...       ...
# GSM475807 -1.362967 -0.360705 -0.365315  0.013773 -0.059107  0.511825
# GSM475808  1.746057 -0.232797  1.142182 -0.329649 -0.051173 -0.824056
# GSM475809 -0.335663 -0.381961  0.477922 -0.097282 -0.377584  0.610227
# GSM475810  0.162101 -0.414464 -0.583495 -0.083815  0.280717 -0.308466
# GSM475811 -0.575474 -0.147313 -0.792014  0.060573 -0.057826  0.275712
#
# ID_REF         THRA    PTPN21      CCL5    CYP2E1  ...  RP11-1260E13.2  \
# ...
