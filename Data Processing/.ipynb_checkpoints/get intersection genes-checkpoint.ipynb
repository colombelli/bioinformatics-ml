# %%
import pandas as pd
import numpy as np

cumida_path="/home/colombelli/Documents/datasets/cumida/full_proc/"
gses=["GSE22820", "GSE42568", "GSE70947"]

dfs = {}
for gse in gses:
    dfs[gse] = pd.read_csv(cumida_path+gse+"_npn.csv", index_col=0)

# %%
tcga = "/home/colombelli/Documents/datasets/assembler/brca_rna_npn.csv"
dfs["tcga"] = pd.read_csv(tcga, index_col=0)

# %%
len(dfs)
# Out:
# 4

# %%
genes = []

for key in dfs:
    g = list(dfs[key].columns)
    genes.append(g)

# %%
genes_intersec = list(set.intersection(*[set(x) for x in genes]))

# %%
len(genes_intersec)
# Out:
# 15237

# %%
no_cls = [x for x in genes_intersec if x != 'class']

# %%
dfs["tcga"].loc[:, no_cls+['class']]
# Out:
#                                  GLIS1     PXMP2    ATP5SL    RHBDF1  \
# TCGA-3C-AAAU-01A-11R-A41B-07 -0.870027  0.045579  0.151762  0.039360
# TCGA-3C-AALI-01A-11R-A41B-07 -1.032134 -0.397413  1.418824  1.683815
# TCGA-3C-AALJ-01A-31R-A41B-07 -0.415394  0.268249  0.505125  0.377335
# TCGA-3C-AALK-01A-11R-A41B-07  2.104695  0.557531  0.458651  0.974175
# TCGA-4H-AAAK-01A-12R-A41B-07  2.231959 -0.268249  0.760619  0.675061
# ...                                ...       ...       ...       ...
# TCGA-WT-AB44-01A-11R-A41B-07 -0.041433 -1.364766 -1.459257  2.592532
# TCGA-XX-A899-01A-11R-A36F-07  1.184317  0.422171  0.401896  0.535916
# TCGA-XX-A89A-01A-11R-A36F-07  0.791318 -1.727564 -0.760619  0.791318
# TCGA-Z7-A8R5-01A-42R-A41B-07 -0.053873  1.082579  0.941548  0.677659
# TCGA-Z7-A8R6-01A-11R-A41B-07 -0.012427  1.304709  0.685480  0.987516
#
#                                  ARL11     ZFP37    BTN3A2      LGI3  \
# TCGA-3C-AAAU-01A-11R-A41B-07  0.474800  0.567220 -1.339160  1.314395
# TCGA-3C-AALI-01A-11R-A41B-07 -0.223431 -0.055947 -0.873044 -0.355201
# TCGA-3C-AALJ-01A-31R-A41B-07  1.418824 -0.811243 -0.107902 -1.302306
# TCGA-3C-AALK-01A-11R-A41B-07 -1.097502  0.337617 -0.366245 -0.101655
# TCGA-4H-AAAK-01A-12R-A41B-07  0.324498  0.000000 -0.095412 -0.076704
# ...                                ...       ...       ...       ...
# TCGA-WT-AB44-01A-11R-A41B-07  0.755113 -0.082936 -1.755471 -0.118323
# TCGA-XX-A899-01A-11R-A36F-07  0.495746 -0.444903 -0.613994 -0.521644
# TCGA-XX-A89A-01A-11R-A36F-07  0.291934 -0.014498 -0.472486  0.980824
# TCGA-Z7-A8R5-01A-42R-A41B-07  0.189585  0.107902 -0.725229  0.447188
# TCGA-Z7-A8R6-01A-11R-A41B-07 -1.053428 -1.643044 -0.811243 -0.596612
#
#                                  TYRO3      SDF4  ...    SLC4A4     FOXC2  \
# TCGA-Z7-A8R5-01A-42R-A41B-07 -0.447188 -0.370676 -0.008284      1
# TCGA-Z7-A8R6-01A-11R-A41B-07 -1.319284  1.159778 -0.928773      1
#
# [1215 rows x 15237 columns]

# %%
tcga_file_name = "/home/colombelli/Documents/datasets/brca_rnaseq_genes_intersec.csv"
dfs["tcga"].loc[:, no_cls+['class']].to_csv(tcga_file_name)

# %%
base_path = "/home/colombelli/Documents/datasets/cumida/intersect_genes/"
for key in dfs:
    if key != "tcga":
        file_name = key+".csv"
        dfs[key].loc[:, no_cls+['class']].to_csv(base_path+file_name)

# %% [markdown]
# ### Intersection between new microarray lung cancer data and cumida

# %%
import pandas as pd
import numpy as np

cumida_path="/home/colombelli/Documents/datasets/cumida/lung/"
gses=["GSE18842", "GSE19804", "GSE27262"]

dfs = {
dfs['GSE19188'] = pd.read_csv("/home/colombelli/Documents/datasets/lung cancer/GSE19188/GSE19188.csv", index_col=0)
for gse in gses:
    dfs[gse] = pd.read_csv(cumida_path+gse+"/translated.csv", index_col=0)

# %%
genes = []
for key in dfs:
    g = list(dfs[key].columns)
    genes.append(g)

# %%
genes_intersec = list(set.intersection(*[set(x) for x in genes]))

# %%
no_cls = [x for x in genes_intersec if x != 'class']

# %%
dfs["GSE19188"].loc[:, no_cls+['class']]
# Out:
#            LOC100129361  SERPINB1       TTL    LRRIQ1  LINC01351   GYLTL1B  \
# GSM475656      0.283047 -1.119187  0.505397  0.172111  -0.039396  0.914058
# GSM475657     -0.229313  0.613589  0.145693  0.872938   0.133322 -0.449574
# GSM475658      0.148243  1.078988 -0.099579 -0.146321  -0.233358 -0.982894
# GSM475659      0.051882  0.156784  0.279828 -0.252826  -0.022794 -0.721077
# GSM475660     -0.184539  0.018388 -0.340966 -0.072073   0.267527 -0.111380
# ...                 ...       ...       ...       ...        ...       ...
# GSM475807     -0.246902  0.480271 -0.180283 -0.174734  -0.017654 -0.773151
# GSM475808      0.094814 -0.938351  0.503440  0.230821   0.018233  0.648693
# GSM475809     -0.319752  0.496844 -0.231009 -0.001372  -0.059987 -0.599415
# GSM475810      0.082764 -0.267538 -0.308885  0.053020   0.115522  0.674336
# GSM475811     -0.070457  0.454061  0.021774 -0.472008   0.039625 -0.669239
#
#             DENND6B   ANAPC10  RP3-452M16.1     SENP5  ...  HIST1H2AG  \
# GSM475656 -0.020030 -1.562953     -0.061193  0.203773  ...  -0.073719
# GSM475657  0.246371  0.045539     -0.007339 -0.365638  ...  -0.279091
# GSM475658 -0.134228  0.356406     -0.041100 -0.281660  ...  -0.286982
# GSM475659 -0.149732  0.614511     -0.046475 -0.367880  ...  -0.540177
# GSM475660  0.355072 -0.027996     -0.026988 -0.430526  ...  -0.331764
# ...             ...       ...           ...       ...  ...        ...
# GSM475807  0.108062 -0.149142      0.001800 -0.142333  ...   0.045784
# GSM475808 -0.056590 -0.701800      0.229638  0.750378  ...   0.567975
# GSM475809 -0.014226  0.300496     -0.150038 -0.343752  ...  -0.283688
# GSM475810  0.289586  0.142937     -0.052707 -0.093689  ...  -0.033873
# GSM475811  0.142300  0.623465      0.177412 -0.491962  ...  -0.119627
#
#              HOXC11      NPC1     DHX58     HEMK1     PVRL1    PCYT1A  \
# GSM475656  0.276036 -0.708236 -0.034944  0.116381  0.067502 -0.224673
# GSM475657 -0.501253  0.462733 -0.046440 -0.045887 -0.463322 -0.287228
# GSM475658 -0.519261  0.807285  0.217587  0.033366 -0.492555 -0.092672
# GSM475659 -0.397648  0.602318  0.351534  0.051766 -0.328122 -0.125726
# GSM475660  0.052240  0.194151  0.221707  0.081119 -0.029031 -0.182179
# ...             ...       ...       ...       ...       ...       ...
# GSM475807 -0.135980 -0.337270 -0.104980  0.396200 -0.150629 -0.050316
# GSM475808  0.199294 -0.602067  0.228751  0.581111  0.278011  0.595946
# GSM475809 -0.243452  0.113661 -0.182911 -0.006545 -0.569913 -0.120528
# GSM475810  0.491152 -0.711067 -0.519157  0.454269 -0.086284 -0.276012
# GSM475811 -0.271172 -0.140387 -0.036114 -0.034755 -0.270302 -0.464764
#
#             RUNX1T1  RP11-373D23.2  class
# GSM475656 -0.482992      -1.404606      1
# GSM475657  0.615379      -0.121180      0
# GSM475658  0.557256       0.340770      0
# GSM475659  0.620313      -0.276525      0
# GSM475660  0.223256       0.242728      0
# ...             ...            ...    ...
# GSM475807 -0.275348       0.883697      0
# GSM475808 -0.587390       0.961977      1
# GSM475809  0.116076       0.537105      0
# GSM475810  0.253231      -0.211161      1
# GSM475811  0.047241      -0.560084      0
#
# [156 rows x 22879 columns]

# %%
base_path = "/home/colombelli/Documents/datasets/lung cancer/intersect/"
for key in dfs:
    file_name = key+".csv"
    dfs[key].loc[:, no_cls+['class']].to_csv(base_path+file_name)

# %% [markdown]
# ### Intersection between microarrays brca data (tcga + cumida)

# %%
import pandas as pd
import numpy as np

cumida_path="/home/colombelli/Documents/datasets/cumida/full_proc/"
gses=["GSE22820", "GSE42568", "GSE70947"]

dfs = {}
dfs['tcga'] = pd.read_csv("/home/colombelli/Documents/datasets/assembler/brca_microarray_no_drops.csv", index_col=0)
for gse in gses:
    dfs[gse] = pd.read_csv(cumida_path+gse+".csv", index_col=0)

# %%
genes = []
for key in dfs:
    g = list(dfs[key].columns)
    genes.append(g)
    
genes_intersec = list(set.intersection(*[set(x) for x in genes]))
no_cls = [x for x in genes_intersec if x != 'class']

# %%
base_path = "/home/colombelli/Documents/datasets/cumida/breast/intersect/"
for key in dfs:
    file_name = key+".csv"
    dfs[key].loc[:, no_cls+['class']].to_csv(base_path+file_name)
