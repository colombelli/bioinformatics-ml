# %%
library(huge)
basedir <- "/home/colombelli/Documents/datasets/assembler/"
rnaseq.file <- "brca_rna_symb_no_log.csv"
df <- read.csv(paste(basedir, rnaseq.file, sep=""), header=T, row.names=1,sep=",")

# %%
df
# Out:
#                              A1BG      A1CF   A2BP1  A2LD1    A2M
# TCGA-3C-AAAU-01A-11R-A41B-07 197.0897  0.0000 0.0000 102.9634  5798.375
# TCGA-3C-AALI-01A-11R-A41B-07 237.3844  0.0000 0.0000  70.8646  7571.979
# TCGA-3C-AALJ-01A-31R-A41B-07 423.2366  0.9066 0.0000 161.2602  8840.399
# TCGA-3C-AALK-01A-11R-A41B-07 191.0178  0.0000 0.0000  62.5072 10960.219
# TCGA-4H-AAAK-01A-12R-A41B-07 268.8809  0.4255 3.8298 154.3702  9585.443
# TCGA-5L-AAT0-01A-12R-A41B-07 203.7718  0.0000 0.5866 111.5354 12331.321
# TCGA-5L-AAT1-01A-12R-A41B-07 211.2958  0.0000 0.0000 101.9723 15406.626
# TCGA-5T-A9QA-01A-11R-A41B-07 314.1841  0.5230 0.5230 233.6192  3182.484
# TCGA-A1-A0SB-01A-11R-A144-07  49.1992  0.0000 4.5050  37.8962 31626.949
# TCGA-A1-A0SD-01A-11R-A115-07 142.2976  0.0000 0.3308  66.8630 23793.493
# TCGA-A1-A0SE-01A-11R-A084-07 192.8194  0.0000 0.0000  70.9305 15728.487
# TCGA-A1-A0SF-01A-11R-A144-07 326.0194  0.0000 0.4284 161.3454 15583.990
# ...

# %%
cls.cols <- df$class
df$class <- NULL

# %%
npn.df <- huge.npn(df, npn.func = "shrinkage", npn.thresh = NULL, verbose = TRUE)
npn.df
# Out:
# Conducting the nonparanormal (npn) transformation via shrunkun ECDF....done.
#                              A1BG        A1CF      A2BP1      A2LD1
# TCGA-3C-AAAU-01A-11R-A41B-07  0.51454717 -0.239382 -0.6634267  0.48641083
# TCGA-3C-AALI-01A-11R-A41B-07  0.81124320 -0.239382 -0.6634267 -0.38178301
# TCGA-3C-AALJ-01A-31R-A41B-07  1.48965314  1.805237 -0.6634267  1.31928385
# TCGA-3C-AALK-01A-11R-A41B-07  0.46786435 -0.239382 -0.6634267 -0.66471507
# TCGA-4H-AAAK-01A-12R-A41B-07  0.97749378  1.359574  1.4773321  1.27172733
# TCGA-5L-AAT0-01A-12R-A41B-07  0.56721980 -0.239382  0.4701738  0.66471507
# TCGA-5L-AAT1-01A-12R-A41B-07  0.61149995 -0.239382 -0.6634267  0.45865094
# TCGA-5T-A9QA-01A-11R-A41B-07  1.15575498  1.554906  0.4289671  1.89549234
# TCGA-A1-A0SB-01A-11R-A144-07 -1.16381957 -0.239382  1.5618022 -1.44164205
# TCGA-A1-A0SD-01A-11R-A115-07  0.10581931 -0.239382  0.1580499 -0.50512458
# TCGA-A1-A0SE-01A-11R-A084-07  0.48641083 -0.239382 -0.6634267 -0.37733451
# ...

# %%
npn.df <- as.data.frame(npn.df)
npn.df$class <- cls.cols
npn.df
# Out:
#                              A1BG        A1CF      A2BP1      A2LD1
# TCGA-3C-AAAU-01A-11R-A41B-07  0.51454717 -0.239382 -0.6634267  0.48641083
# TCGA-3C-AALI-01A-11R-A41B-07  0.81124320 -0.239382 -0.6634267 -0.38178301
# TCGA-3C-AALJ-01A-31R-A41B-07  1.48965314  1.805237 -0.6634267  1.31928385
# TCGA-3C-AALK-01A-11R-A41B-07  0.46786435 -0.239382 -0.6634267 -0.66471507
# TCGA-4H-AAAK-01A-12R-A41B-07  0.97749378  1.359574  1.4773321  1.27172733
# TCGA-5L-AAT0-01A-12R-A41B-07  0.56721980 -0.239382  0.4701738  0.66471507
# TCGA-5L-AAT1-01A-12R-A41B-07  0.61149995 -0.239382 -0.6634267  0.45865094
# TCGA-5T-A9QA-01A-11R-A41B-07  1.15575498  1.554906  0.4289671  1.89549234
# TCGA-A1-A0SB-01A-11R-A144-07 -1.16381957 -0.239382  1.5618022 -1.44164205
# TCGA-A1-A0SD-01A-11R-A115-07  0.10581931 -0.239382  0.1580499 -0.50512458
# TCGA-A1-A0SE-01A-11R-A084-07  0.48641083 -0.239382 -0.6634267 -0.37733451
# TCGA-A1-A0SF-01A-11R-A144-07  1.20958274 -0.239382  0.3027525  1.32420436
# ...

# %%
save.file <- "brca_rna_npn.csv"
savedir <- paste(basedir, save.file, sep="")
savedir
# Out:
# [1] "/home/colombelli/Documents/datasets/assembler/brca_rna_npn.csv"

# %%
write.csv(npn.df, file = savedir, row.names = TRUE)

# %%
micarr.file <- "brca_microarray_no_drops.csv"
df <- read.csv(paste(basedir, micarr.file, sep=""), header=T, row.names=1,sep=",")
df
# Out:
#                              X15E1.2  X2..PDE    X7A5    A1BG        A2BP1
# TCGA-A1-A0SD-01A-11R-A115-07 -1.44775  0.0153750  2.4105  0.94933333  0.5391667
# TCGA-A1-A0SE-01A-11R-A084-07 -2.29950  0.4669375  0.3635  0.27983333 -1.5346667
# TCGA-A1-A0SH-01A-11R-A084-07 -1.94400 -0.0295625  1.8550  0.74866667 -1.3048333
# TCGA-A1-A0SJ-01A-11R-A084-07 -2.09800  0.7919375  1.4080  0.75000000 -1.3578333
# TCGA-A1-A0SK-01A-12R-A084-07 -1.28500 -0.1911250 -1.3005 -0.54716667 -2.1845000
# TCGA-A1-A0SM-01A-11R-A084-07 -2.15400  0.3263125  2.1600  0.59766667 -1.1756667
# TCGA-A1-A0SO-01A-22R-A084-07  0.53450  0.4107500  1.5635  1.54233333 -1.5748333
# TCGA-A1-A0SP-01A-11R-A084-07 -1.18700 -0.3287333  1.5940 -1.29116667 -1.1338333
# TCGA-A2-A04N-01A-11R-A115-07 -0.94900 -0.1181875  2.6455  0.08566667 -1.2888333
# TCGA-A2-A04P-01A-31R-A034-07 -1.59900 -0.3471250  1.7275 -0.15683333 -0.8194000
# TCGA-A2-A04Q-01A-21R-A034-07 -1.05050  0.0389375 -0.0660  0.22600000 -1.1005000
# ...

# %%
cls.cols <- df$class
df$class <- NULL

# %%
npn.df <- huge.npn(df, npn.func = "shrinkage", npn.thresh = NULL, verbose = TRUE)
npn.df
# Out:
# Conducting the nonparanormal (npn) transformation via shrunkun ECDF....done.
#                              X15E1.2     X2..PDE      X7A5        A1BG
# TCGA-A1-A0SD-01A-11R-A115-07 -0.02553862 -0.51525740   1.14586469  1.32611279
# TCGA-A1-A0SE-01A-11R-A084-07 -1.84503397  0.75425075  -0.59449404  0.14520346
# TCGA-A1-A0SH-01A-11R-A084-07 -0.96218659 -0.63031827   0.68292871  1.05333565
# TCGA-A1-A0SJ-01A-11R-A084-07 -1.29638477  1.62216354   0.19702114  1.06070657
# TCGA-A1-A0SK-01A-12R-A084-07  0.22748122 -0.99628065  -1.62216354 -1.00323696
# TCGA-A1-A0SM-01A-11R-A084-07 -1.38929851  0.34270492   0.90343630  0.77124586
# TCGA-A1-A0SO-01A-22R-A084-07  2.59433872  0.58943802   0.33145374  2.18462107
# TCGA-A1-A0SP-01A-11R-A084-07  0.36079659 -1.35703988   0.36988579 -1.74171948
# TCGA-A2-A04N-01A-11R-A115-07  0.67758567 -0.77695967   1.34141866 -0.09376650
# TCGA-A2-A04P-01A-31R-A034-07 -0.27578140 -1.42304467   0.50799679 -0.42508795
# ...

# %%
npn.df <- as.data.frame(npn.df)
npn.df$class <- cls.cols
npn.df
# Out:
#                              X15E1.2     X2..PDE      X7A5        A1BG
# TCGA-A1-A0SD-01A-11R-A115-07 -0.02553862 -0.51525740   1.14586469  1.32611279
# TCGA-A1-A0SE-01A-11R-A084-07 -1.84503397  0.75425075  -0.59449404  0.14520346
# TCGA-A1-A0SH-01A-11R-A084-07 -0.96218659 -0.63031827   0.68292871  1.05333565
# TCGA-A1-A0SJ-01A-11R-A084-07 -1.29638477  1.62216354   0.19702114  1.06070657
# TCGA-A1-A0SK-01A-12R-A084-07  0.22748122 -0.99628065  -1.62216354 -1.00323696
# TCGA-A1-A0SM-01A-11R-A084-07 -1.38929851  0.34270492   0.90343630  0.77124586
# TCGA-A1-A0SO-01A-22R-A084-07  2.59433872  0.58943802   0.33145374  2.18462107
# TCGA-A1-A0SP-01A-11R-A084-07  0.36079659 -1.35703988   0.36988579 -1.74171948
# TCGA-A2-A04N-01A-11R-A115-07  0.67758567 -0.77695967   1.34141866 -0.09376650
# TCGA-A2-A04P-01A-31R-A034-07 -0.27578140 -1.42304467   0.50799679 -0.42508795
# TCGA-A2-A04Q-01A-21R-A034-07  0.55940476 -0.47683018  -0.84155909  0.04683262
# ...

# %%
save.file <- "brca_micarr_npn.csv"
savedir <- paste(basedir, save.file, sep="")
savedir
# Out:
# [1] "/home/colombelli/Documents/datasets/assembler/brca_micarr_npn.csv"

# %%
write.csv(npn.df, file = savedir, row.names = TRUE)

# %%
library(huge)
basedir <- "/home/colombelli/Documents/datasets/cumida/full_proc/"
gse <- "GSE22820.csv"
df <- read.csv(paste(basedir, gse, sep=""), header=T, row.names=1, sep=",")
df
# Out:
#               class APOBEC3B  AA085955 ATP11B    LOC100132006 DNAJA1
# GSM563920_1   1      7.642101 4.803022  7.939666 5.790127     11.77294
# GSM563922_3   1      4.758954 5.150573  6.568998 5.352497     12.48660
# GSM563923_4   1      6.423254 4.408955  8.668739 4.979653     11.25823
# GSM563924_5   1      8.385947 4.454648  8.721586 5.121018     10.93543
# GSM563925_6   1      7.630389 4.598275  8.387313 5.221780     11.64716
# GSM563926_7   1      8.920266 4.713536  7.220090 6.337220     11.71187
# GSM563927_8   1      8.381502 4.788302  7.502661 5.438383     12.31898
# GSM563928_9   1      9.209772 4.689143  8.787514 5.216824     12.35964
# GSM563929_10  1      8.174604 4.922422  8.908414 6.405099     11.77223
# GSM563930_11  1      8.582873 5.439284  8.463425 5.439284     11.96810
# GSM563931_12  1      7.780753 4.524714  9.077205 4.972887     12.19858
# GSM563933_14  1      7.793722 4.543560  9.486734 5.149267     12.03057
# ...

# %%
cls.cols <- df$class
df$class <- NULL

npn.df <- huge.npn(df, npn.func = "shrinkage", npn.thresh = NULL, verbose = TRUE)
npn.df
# Out:
# Conducting the nonparanormal (npn) transformation via shrunkun ECDF....done.
#               APOBEC3B    AA085955    ATP11B      LOC100132006 DNAJA1
# GSM563920_1    0.00000000  0.62530896 -0.83892874  1.35992446   0.49710267
# GSM563922_3   -2.51768312  1.69029558 -2.08104646  0.29853253   1.50571343
# GSM563923_4   -0.91849343 -1.35992446  0.14770000 -0.94626232  -0.62530896
# GSM563924_5    0.74005220 -0.86487249  0.24139036 -0.47651849  -1.06506667
# GSM563925_6   -0.01840011  0.09211888 -0.29853253 -0.18498553   0.22251626
# GSM563926_7    1.03406995  0.41585784 -1.40541103  2.24983436   0.33713567
# GSM563927_8    0.71640118  0.60331001 -1.16447583  0.41585784   1.23731086
# GSM563928_9    1.20013970  0.31777804  0.39596562 -0.20371692   1.31695666
# GSM563929_10   0.56011519  0.97473997  0.64759829  2.51768312   0.47651849
# GSM563930_11   0.86487249  2.08104646 -0.26034626  0.43590713   0.74005220
# GSM563931_12   0.12913296 -0.26034626  1.00398660 -0.97473997   1.09706402
# ...

# %%
npn.df <- as.data.frame(npn.df)
npn.df$class <- cls.cols
npn.df
# Out:
#               APOBEC3B    AA085955    ATP11B      LOC100132006 DNAJA1
# GSM563920_1    0.00000000  0.62530896 -0.83892874  1.35992446   0.49710267
# GSM563922_3   -2.51768312  1.69029558 -2.08104646  0.29853253   1.50571343
# GSM563923_4   -0.91849343 -1.35992446  0.14770000 -0.94626232  -0.62530896
# GSM563924_5    0.74005220 -0.86487249  0.24139036 -0.47651849  -1.06506667
# GSM563925_6   -0.01840011  0.09211888 -0.29853253 -0.18498553   0.22251626
# GSM563926_7    1.03406995  0.41585784 -1.40541103  2.24983436   0.33713567
# GSM563927_8    0.71640118  0.60331001 -1.16447583  0.41585784   1.23731086
# GSM563928_9    1.20013970  0.31777804  0.39596562 -0.20371692   1.31695666
# GSM563929_10   0.56011519  0.97473997  0.64759829  2.51768312   0.47651849
# GSM563930_11   0.86487249  2.08104646 -0.26034626  0.43590713   0.74005220
# GSM563931_12   0.12913296 -0.26034626  1.00398660 -0.97473997   1.09706402
# GSM563933_14   0.18498553 -0.16631539  1.56174552 -0.32744233   0.89137957
# ...

# %%
gse
# Out:
# [1] "GSE22820.csv"

# %%
save.file <- "GSE22820_npn.csv"
savedir <- paste(basedir, save.file, sep="")
savedir
# Out:
# [1] "/home/colombelli/Documents/datasets/cumida/full_proc/GSE22820_npn.csv"

# %%
write.csv(npn.df, file = savedir, row.names = TRUE)

# %%
gse <- "GSE42568.csv"
df <- read.csv(paste(basedir, gse, sep=""), header=T, row.names=1, sep=",")

cls.cols <- df$class
df$class <- NULL

npn.df <- huge.npn(df, npn.func = "shrinkage", npn.thresh = NULL, verbose = TRUE)
npn.df <- as.data.frame(npn.df)
npn.df$class <- cls.cols

npn.df
# Out:
# Conducting the nonparanormal (npn) transformation via shrunkun ECDF....done.
#     DDR1        RFC2        HSPA6       PAX8        GUCA1A      MIR5193
# 191 -1.21418843 -0.49347835  0.12186998 -1.2595313  -1.05257697 -0.37270991
# 194 -0.44445074 -2.18532382 -0.54364665  2.4606577   2.01121282 -1.12991701
# 195 -1.53540443  0.09963508 -0.09963508 -0.1218700  -0.25685601 -0.25685601
# 196 -1.30744616  0.44445074  0.32588561 -0.4203149  -0.73107746 -0.03316587
# 197 -1.77458741  0.18895836 -0.73107746  0.2114857   0.49347835 -0.44445074
# 198 -1.41281295 -0.51840930  1.12991701  0.1218700  -0.27972323  0.14416162
# 199 -1.68456271  0.30272868  0.23411426 -0.7890742   0.27972323 -0.64814960
# 200 -0.56921351 -0.88110247 -1.09048115  1.2141884   1.47151323  0.21148568
# 201 -1.05257697 -1.09048115 -1.21418843 -0.6753038   1.41281295 -0.62143708
# 202 -1.25953127  0.64814960  0.30272868 -1.0904812  -0.59513472 -0.09963508
# ...

# %%
save.file <- "GSE42568_npn.csv"
savedir <- paste(basedir, save.file, sep="")
savedir
# Out:
# [1] "/home/colombelli/Documents/datasets/cumida/full_proc/GSE42568_npn.csv"

# %%
write.csv(npn.df, file = savedir, row.names = TRUE)

# %%
gse <- "GSE70947.csv"
df <- read.csv(paste(basedir, gse, sep=""), header=T, row.names=1, sep=",")

cls.cols <- df$class
df$class <- NULL

npn.df <- huge.npn(df, npn.func = "shrinkage", npn.thresh = NULL, verbose = TRUE)
npn.df <- as.data.frame(npn.df)
npn.df$class <- cls.cols

npn.df
# Out:
# Conducting the nonparanormal (npn) transformation via shrunkun ECDF....done.
#                                               U2AF1L4     PSMC3IP
# GSM1823702_252800417016_S01_GE1_107_Sep09_1_2 -0.30283148  0.26631745
# GSM1823703_252800417016_S01_GE1_107_Sep09_2_1  1.48047610 -1.17230766
# GSM1823704_252800416877_S01_GE1_107_Sep09_2_3  0.34903766  0.78170895
# GSM1823705_252800416894_S01_GE1_107_Sep09_1_1  0.56292057  0.47293610
# GSM1823706_252800416894_S01_GE1_107_Sep09_1_3  0.03511303 -0.09668752
# GSM1823707_252800416894_S01_GE1_107_Sep09_2_1  1.01552802  0.89269193
# GSM1823708_252800416894_S01_GE1_107_Sep09_2_3  1.30126564  0.04389622
# GSM1823709_252800416859_S01_GE1_107_Sep09_1_1  1.80252508  1.17230766
# GSM1823710_252800416923_S01_GE1_107_Sep09_1_1  1.24353580 -0.65756565
# GSM1823711_252800416923_S01_GE1_107_Sep09_1_3 -1.89450435 -0.90568209
# GSM1823712_252800416923_S01_GE1_107_Sep09_2_1  0.57318385 -0.16751041
# ...

# %%
save.file <- "GSE70947_npn.csv"
savedir <- paste(basedir, save.file, sep="")
savedir
# Out:
# [1] "/home/colombelli/Documents/datasets/cumida/full_proc/GSE70947_npn.csv"

# %%
write.csv(npn.df, file = savedir, row.names = TRUE)
