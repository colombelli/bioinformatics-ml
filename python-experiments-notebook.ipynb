# %%
#GSE25011
#GSE1563

import GEOparse

gse = GEOparse.get_GEO(filepath="./GDS4088.soft.gz")#(geo="GSE1563", destdir="./")
# Out:
# 18-Sep-2019 18:16:59 INFO GEOparse - Parsing ./GDS4088.soft.gz:
# 18-Sep-2019 18:16:59 DEBUG GEOparse - DATABASE: Geo
# 18-Sep-2019 18:16:59 DEBUG GEOparse - DATASET: GDS4088
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_1
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_2
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_3
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_4
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_5
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_6
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_7
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_8
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_9
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_10
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_11
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_12
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_13
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_14
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_15
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_16
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_17
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_18
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_19
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_20
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_21
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_22
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_23
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_24
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_25
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_26
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_27
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_28
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_29
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_30
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_31
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_32
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_33
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_34
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_35
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_36
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_37
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_38
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_39
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_40
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_41
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_42
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_43
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_44
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_45
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_46
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_47
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_48
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_49
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_50
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_51
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_52
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_53
# 18-Sep-2019 18:16:59 DEBUG GEOparse - SUBSET: GDS4088_54
# 18-Sep-2019 18:16:59 DEBUG GEOparse - DATASET: GDS4088

# %%
gse.columns
# Out:
#                                                  description individual  \
# GSM614415  Value for GSM614415: MD40-T0; src: breast canc...       MD40
# GSM614416  Value for GSM614416: MD40-T20; src: breast can...       MD40
# GSM614417  Value for GSM614417: MD40-T40; src: breast can...       MD40
# GSM614418  Value for GSM614418: MD40-T60; src: breast can...       MD40
# GSM614419  Value for GSM614419: MD40-T120; src: breast ca...       MD40
# ...                                                      ...        ...
# GSM614472  Value for GSM614472: MD71-T60; src: breast can...       MD71
# GSM614473  Value for GSM614473: MD71-T120; src: breast ca...       MD71
# GSM614474  Value for GSM614474: MD71-T180; src: breast ca...       MD71
# GSM614475  Value for GSM614475: MD71-T0-F (no RNAlater); ...       MD71
# GSM614476  Value for GSM614476: MD71-T40-F (no RNAlater);...       MD71
#
#                protocol      time    other
# GSM614415      RNAlater  baseline  RIN 8.6
# GSM614416      RNAlater    20 min  RIN 8.6
# GSM614417      RNAlater    40 min  RIN 8.5
# GSM614418      RNAlater    60 min  RIN 8.7
# GSM614419      RNAlater   120 min  RIN 7.4
# ...                 ...       ...      ...
# GSM614472      RNAlater    60 min  RIN 8.4
# GSM614473      RNAlater   120 min  RIN 9.2
# GSM614474      RNAlater   180 min  RIN 8.5
# GSM614475  flash frozen  baseline  RIN 7.1
# GSM614476  flash frozen    40 min  RIN 7.3
#
# [86 rows x 5 columns]

# %%
import pylab as pl

# %%
import seaborn as sns

# %%
pl.rcParams['figure.figsize'] = (14, 10)
pl.rcParams['ytick.labelsize'] = 12
pl.rcParams['xtick.labelsize'] = 11
pl.rcParams['axes.labelsize'] = 23
pl.rcParams['legend.fontsize'] = 20
sns.set_style('ticks')
c1, c2, c3, c4 = sns.color_palette("Set1", 4)

# %%
controls = [
    'GSM614415',
    'GSM614416',
    'GSM614417',
    'GSM614418',
    'GSM614419',
    'GSM614420',
    'GSM614421',
    
]
