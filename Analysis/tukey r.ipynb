# %% [markdown]
# ## Breast

# %%
df <- read.csv(file = "/home/colombelli/Documents/arrayexpress/breast/all_exps_results.csv")

# %%
library(agricolae)
data("PlantGrowth")
# Out:
# Error in library(agricolae): there is no package called ‘agricolae’
# Traceback:
#
# 1. library(agricolae)

# %%
anova <- aov(Stability~Type,df)

# %%
summary(anova)
# Out:
#              Df Sum Sq Mean Sq F value Pr(>F)
# Type         14 17.892   1.278   183.8 <2e-16 ***
# Residuals   765  5.318   0.007
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
TukeyHSD(anova)
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = Stability ~ Type, data = df)
#
# $Type
#                                    diff          lwr         upr     p adj
# GR-GeoDE                   0.2418099529  0.186174605  0.29744530 0.0000000
# Het-GeoDE                  0.0583508155  0.002715468  0.11398616 0.0292092
# Het Wx-GR-SU-GeoDE         0.3831257778  0.327490430  0.43876113 0.0000000
# Hom GeoDE-GeoDE            0.0326559268 -0.022979421  0.08829127 0.7997911
# Hom GR-GeoDE               0.2421499416  0.186514594  0.29778529 0.0000000
# Hom ReliefF-GeoDE          0.0191144644 -0.036520883  0.07474981 0.9979183
# Hom SU-GeoDE               0.3990363355  0.343400988  0.45467168 0.0000000
# Hom Wx-GeoDE               0.3849004114  0.329265064  0.44053576 0.0000000
# Hyb Borda-GeoDE            0.2419928793  0.186357532  0.29762823 0.0000000
# Hyb Stb-GeoDE              0.2838706209  0.228235273  0.33950597 0.0000000
# ...

# %%
library(dplyr)

df %>%
  group_by(Type) %>%
  summarise_at(vars(-th_frac), funs(mean(., na.rm=TRUE)))
# Out:
#    Type         Threshold Stability Accuracy  std_ACC    ROC.AUC   std_ROC_AUC
# 1  GeoDE        27.88462  0.1513844 0.8990100 0.01676512 0.9587627 0.015249723
# 2  GR           27.88462  0.3931944 0.9154650 0.01929197 0.9670491 0.015965408
# 3  Het          27.88462  0.2097352 0.8871928 0.01873721 0.9474333 0.028584521
# 4  Het Wx-GR-SU 27.88462  0.5345102 0.9141304 0.01414406 0.9688219 0.010783100
# 5  Hom GeoDE    27.88462  0.1840404 0.9011367 0.02188333 0.9657372 0.015723379
# 6  Hom GR       27.88462  0.3935344 0.9212721 0.02063934 0.9741402 0.012849530
# 7  Hom ReliefF  27.88462  0.1704989 0.6608427 0.02025856 0.7058954 0.035913812
# 8  Hom SU       27.88462  0.5504208 0.9339714 0.01388591 0.9809826 0.008414074
# 9  Hom Wx       27.88462  0.5362848 0.8978018 0.01805488 0.9612826 0.009010667
# 10 Hyb Borda    27.88462  0.3933773 0.9132814 0.01732767 0.9712246 0.014311889
# 11 Hyb Stb      27.88462  0.4352550 0.9251048 0.01858731 0.9746604 0.012558605
# ...

# %%
df
# Out:
#     th_frac     Threshold Stability Accuracy  std_ACC     ROC.AUC   std_ROC_AUC
# 1   0.004867127  1        0.2999659 0.7176082 0.042120564 0.8072956 0.023212911
# 2   0.009734255  2        0.3499367 0.8318627 0.034454062 0.9074529 0.023355496
# 3   0.014601382  3        0.2665596 0.8496576 0.037342281 0.9334462 0.015468218
# 4   0.019468510  4        0.4748978 0.8753089 0.024837781 0.9413184 0.020777310
# 5   0.024335637  5        0.4398637 0.8761766 0.037374541 0.9502331 0.011857280
# 6   0.029202765  6        0.4164963 0.8887683 0.039737854 0.9591427 0.010139504
# 7   0.034069892  7        0.4283767 0.8974620 0.037118595 0.9649181 0.013245400
# 8   0.038937019  8        0.4247760 0.9022418 0.030506157 0.9701406 0.013408635
# 9   0.043804147  9        0.4442010 0.8987617 0.032046059 0.9691872 0.011871529
# 10  0.048671274 10        0.4397273 0.8987673 0.029550908 0.9707641 0.010588401
# 11  0.053538402 11        0.4451575 0.9087664 0.027964431 0.9712453 0.007042529
# ...
